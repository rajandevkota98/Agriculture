# %%
from bing_image_downloader import downloader
for i in range(len(Names)):
    # print (Names[i])
    # print(i)
    downloader.download(Names[i], limit=50,  output_dir='final', adult_filter_off=True, force_replace=False, timeout=60, verbose=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [6], in <cell line: 7>()
#       7 for i in range(1, 10):
#       8     url = "sandy soil image" + str(i) + ".jpg"
# ----> 9     urllib.request.urlretrieve(url, "Sandy/sandysoil" + str(i) + ".jpg")
#
# File ~/anaconda3/lib/python3.9/urllib/request.py:239, in urlretrieve(url, filename, reporthook, data)
#     222 """
#     223 Retrieve a URL into a temporary location on disk.
#     224
#    (...)
#     235 data file as well as the resulting HTTPMessage object.
#     236 """
#     237 url_type, path = _splittype(url)
# --> 239 with contextlib.closing(urlopen(url, data)) as fp:
#     240     headers = fp.info()
#     242     # Just return the local path and the "headers" for file://
#     243     # URLs. No sense in performing a copy unless requested.
#
# ...

# %%
Names= ['Sandy_soil', 'Black_soil', 'Red_soil']

# %%
from bing_image_downloader import downloader
for i in range(len(Names)):
    # print (Names[i])
    # print(i)
    downloader.download(Names[i], limit=100,  output_dir='final', adult_filter_off=True, force_replace=False, timeout=60, verbose=True)
# Out:
# [%] Downloading Images to /home/rajan/Agriculture/final/Sandy_soil
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://www.gardeningknowhow.com/wp-content/uploads/2019/01/sandy-soil.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://cdn.wonderfuldiy.com/wp-content/uploads/2016/02/Sandy-Soil.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://www.publicdomainpictures.net/pictures/100000/velka/sandy-soil.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://img-aws.ehowcdn.com/877x500p/photos.demandstudios.com/93/16/fotolia_7473697_XS.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://www.highqualitytextures.com/freetextures/albums/soiltextures/sandtextures/P1010525.jpg
# [Error]Invalid image, not saving https://www.highqualitytextures.com/freetextures/albums/soiltextures/sandtextures/P1010525.jpg
#
# ...

# %%
pip install bing-image-downloader
# Out:
# ...
#   Using cached bing_image_downloader-1.1.2-py3-none-any.whl (5.9 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
